# %%
import re
text="this my Nivetha123@gmail.com"
find=re.findall(r'\w{2,}+d*@\w{2,}\.\w{2,}',text)
find
# Out:
# ['Nivetha123@gmail.com']

# %%
import re
text="this is my email abc@gmail.com and cde@gmail.com"
a=re.findall(r'\w{2,}+@\w{2,}\.\w{2,}',text)
a
# Out:
# ['abc@gmail.com', 'cde@gmail.com']

# %%
text=input("Enter the Text")
a=re.findall(r'abcd',text)
if a:
  print("found")
else:
  print("is not found")
a
# Out:
# Enter the TextNIvethalakshmiabcd123
# found
# ['abcd']

# %%
txt="Many student are the joined in college in BCA depatment and they enjoy the class and also the hostel"
sse=re.search(r'college',txt)
print(sse)
# Out:
# <re.Match object; span=(31, 38), match='college'>

# %%
txt="my phone number is 31234567899"
se=re.search(r'\d{9,}',txt)
print(se)
# Out:
# <re.Match object; span=(19, 30), match='31234567899'>

# %%
txt="my phone number is 31234567899"
extract=re.search(r'\d{9,}',txt)
print(extract)
# Out:
# <re.Match object; span=(19, 30), match='31234567899'>

# %%
txt="my USA amount is $250"
replace=re.sub(r'USA',"the",txt)
print(replace)
# Out:
# my the amount is $250

# %%
txt="abc@gmail.com"
d=re.match(r'\w{2,}@\w{2,}\.\w{2,}',txt)
print(d)
# Out:
# <re.Match object; span=(0, 13), match='abc@gmail.com'>

# %%
import pandas as pd
df=pd.read_csv("")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
data=pd.read_csv("salary_data.csv")
data
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
x=data['YearsExperience']
y=data['Salary']

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y,color="purple",label="data points")
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.bar(x,y,color="purple",label="data points")
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(x,color="purple",label="data points")
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.legend()
plt.show()

# %%
df=pd.read_csv("sales_data.csv")
x=df['Region']
y=df['Sales_Amount']
plt.bar(x,y,color="skyblue")
plt.xlabel("Region")
plt.ylabel("Sales Amount")
plt.title("sales analyst")
plt.show()

# %%
df=pd.read_csv("salary_data.csv")
x=df['YearsExperience']
y=df['Salary']
plt.scatter(x,y,color="skyblue",edgecolor="green",alpha=0.9)
plt.xlabel("Region",color="blue")
plt.ylabel("Sales Amount",color="blue")
plt.title("sales analyst",color="Red")
plt.show()

# %%
df=pd.read_csv("salary_data.csv")
x=df['YearsExperience']
y=df['Salary']
plt.plot(x,y,color="skyblue",marker=".",markeredgecolor="black")
plt.xlabel("Region",color="blue")
plt.ylabel("Sales Amount",color="blue")
plt.title("sales analyst",color="Red")
plt.show()

# %%
df=pd.read_csv("salary_data.csv")
x=df['YearsExperience']
y=df['Salary']
plt.hist(x,color="skyblue",edgecolor='black')
plt.xlabel("Region",color="blue")
plt.ylabel("Sales Amount",color="blue")
plt.title("sales analyst",color="Red")
plt.show()

# %%
import numpy as np
x=np.array(["long vidoe","short video","Live","Post"])
y=np.array([4060,1200,750,300])
plt.pie(y,labels=x,autopct='%1.2f%%',startangle=90 )
plt.tile=("social media")
plt.show()

# %%
df=pd.read_csv("temperatures.csv")
df
# Out:
#      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 0    1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47
# 1    1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80
# 2    1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85
# 3    1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04
# 4    1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112  2013  24.56  26.59  30.62  32.66  34.46  32.44  31.07  30.76  31.04
# 113  2014  23.83  25.97  28.95  32.74  33.77  34.15  31.85  31.32  30.68
# 114  2015  24.58  26.89  29.07  31.87  34.09  32.48  31.88  31.52  31.55
# 115  2016  26.94  29.72  32.62  35.38  35.72  34.03  31.64  31.79  31.66
# 116  2017  26.45  29.46  31.60  34.95  35.84  33.82  31.88  31.72  32.22
#
#        OCT    NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# ...

# %%
days = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
times = ['Morning', 'Afternoon', 'Evening']

temps = np.array([
    [28, 36, 31],
    [27, 35, 30],
    [29, 37, 32],
    [28, 38, 33],
    [30, 39, 34],
    [31, 40, 35],
    [29, 37, 33]
])
plt.imshow(temps ,cmap='OrRd',aspect='auto')
plt.colorbar(label="Temperature (°C)")
plt.title("heat rate")
# Out:
# Text(0.5, 1.0, 'heat rate')

# %%
chennai=[12,34,56,78,90,34,65,43,87,98,12]
salem=[44,55,66,77,88,99,00,11,22,33,32,43]
trichy=[99,98,76,54,32,21,12,34,56]
plt.boxplot([chennai,salem,trichy],labels=["chennai","salem","trichy"])
plt.title("box plot")
plt.show()
# Out:
# /tmp/ipykernel_947/1689183069.py:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([chennai,salem,trichy],labels=["chennai","salem","trichy"])

# %%
df=pd.read_csv("sales_data.csv")
df
# Out:
#      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0          1052  2023-02-03       Bob  North       5053.97             18
# 1          1093  2023-04-21       Bob   West       4384.02             17
# 2          1015  2023-09-21     David  South       4631.23             30
# 3          1072  2023-08-24       Bob  South       2167.94             39
# 4          1061  2023-03-24   Charlie   East       3750.20             13
# ..          ...         ...       ...    ...           ...            ...
# 995        1010  2023-04-15   Charlie  North       4733.88              4
# 996        1067  2023-09-07       Bob  North       4716.36             37
# 997        1018  2023-04-27     David  South       7629.70             17
# 998        1100  2023-12-20     David   West       1629.47             39
# 999        1086  2023-08-16     Alice   East       4923.93             48
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_947/3836726552.py in <cell line: 0>()
# ----> 1 df=pd.read_csv("healthcare_dataset.csv")
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_947/1437638210.py in <cell line: 0>()
# ----> 1 plt.hist(sales_Amount,color="red",edgecolor="black")
#       2 plt.tilte=("sales_data")
#       3 plt.xlabel("amount")
#       4 plt.ylabel("count")
#       5 plt.show
#
# NameError: name 'sales_Amount' is not defined

# %%
df=pd.read_csv("sales_data.csv")
df
# Out:
#      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0          1052  2023-02-03       Bob  North       5053.97             18
# 1          1093  2023-04-21       Bob   West       4384.02             17
# 2          1015  2023-09-21     David  South       4631.23             30
# 3          1072  2023-08-24       Bob  South       2167.94             39
# 4          1061  2023-03-24   Charlie   East       3750.20             13
# ..          ...         ...       ...    ...           ...            ...
# 995        1010  2023-04-15   Charlie  North       4733.88              4
# 996        1067  2023-09-07       Bob  North       4716.36             37
# 997        1018  2023-04-27     David  South       7629.70             17
# 998        1100  2023-12-20     David   West       1629.47             39
# 999        1086  2023-08-16     Alice   East       4923.93             48
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# ...

# %%
x=df["Sales_Amount"]
plt.hist(x,color="skyblue",edgecolor='black')
plt.title("sales")
plt.xlabel("Amount")
plt.ylabel("List")
plt.show()

# %%
from scipy.stats import kurtosis as k
kurto=k(x,fisher=True)
kurto1=k(x,fisher=False)
mean_value=np.mean(x)
min_value=np.min(x)
max_value=np.max(x)
if(kurto>0):
  print("heavy tai more distribution")
  if(max_value-mean_value)>(mean_value-min_value):
    print(" big profits")
  else:
    print("big loss")
elif(kurto<0):
  print("light tail more distribution")
else:
  print("normal distribution")
# Out:
# light tail more distribution

# %%
plt.hist(x,color="skyblue",edgecolor='black')
plt.title("sales")
plt.xlabel("Amount")
plt.ylabel("List")
plt.show()

# %%
mean_val=np.mean(x)
median_val=np.median(x)
mean_val
# Out:
# np.float64(5019.265229999999)

# %%
plt.plot(x, color="pink")
plt.title("sales")

plt.axhline(mean_val, linestyle="--", linewidth=3)
plt.axhline(median_val, linestyle="dotted", linewidth=2)
plt.show()
